# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
plt.show()

# %%
x = [1,2,3,6,7,9]
y = [1,2,3,5,6,7]
plt.plot(x,y)

# %% [markdown]
# # Methods to Plot

# %%
figure = plt.figure()
sub_plot = figure.add_subplot()
plt.show()

# %%
figure = plt.figure()
sub_plot = figure.add_axes(1,2,3,4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c53d37eacd79> in <module>
#       1 figure = plt.figure()
# ----> 2 sub_plot = figure.add_axes(1,2,3,4)
#       3 plt.show()
#
# C:\Users\AI.khan\desktop\f_project\venv\lib\site-packages\matplotlib\figure.py in add_axes(self, *args, **kwargs)
#    1248
#    1249             # create the new axes using the axes class given
# -> 1250             a = projection_class(self, rect, **kwargs)
#    1251
#    1252         return self._add_axes_internal(key, a)
#
# C:\Users\AI.khan\desktop\f_project\venv\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     481             self._position = rect
#     482         else:
# --> 483             self._position = mtransforms.Bbox.from_bounds(*rect)
# ...

# %%
home, sub_plot = plt.subplots()
sub_plot.plot()
sub_plot.set(title = 'Name of Graph',
            xlabel = 'x-axis',
            ylabel = 'y-axis')
plt.show()

# %%
figure = plt.figure()
sub_plot = figure.add_subplot()
sub_plot.plot(x,y)
plt.show()

# %%
home, sub_plot = plt.subplots()
sub_plot.plot(x,y)
plt.show()

# %% [markdown]
# # Multiple Plots in Single Figure

# %%
figure,(sub_plot_1,sub_plot_2) = plt.subplots(nrows=1,ncols=2, figsize=(10,5))

# %%
figure,((sub_plot_1,sub_plot_2),(sub_plot_3,sub_plot_4)) = plt.subplots(nrows=2,ncols=2, figsize=(10,10))

# %%
figure,((sub_plot_1,sub_plot_2),(sub_plot_3,sub_plot_4)) = plt.subplots(nrows=2,ncols=2, figsize=(10,10))
sub_plot_1.plot(x,y)
sub_plot_2.plot()
sub_plot_3.plot(x,y)
sub_plot_4.plot(x,y)
plt.show()

# %%
figure, sub_plot = plt.subplots()
sub_plot.plot(x,y); # use semi-colon to remove path address

# %%
figure, sub_plot=plt.subplots()
sub_plot.scatter(x,y);

# %%
figure, sub_plot=plt.subplots()
sub_plot.bar(x,y);

# %%
shop = { 'item1':10,
       'item2':50,'item3':30,'item4':20, 'item5':80}
figure, sub_plot=plt.subplots()
sub_plot.bar(shop.keys(), shop.values());

# %%
shop = { 'item1':10,
       'item2':50,'item3':30,'item4':20, 'item5':80}
figure, sub_plot=plt.subplots()
sub_plot.barh(list(shop.keys()), list(shop.values()));

# %%
figure, sub_plot=plt.subplots()
sub_plot.hist(x);

# %%
a =np.random.randn(1000)
figure, sub_plot=plt.subplots()
sub_plot.hist(a);

# %%
figure, ((sub_plot1,sub_plot2),(sub_plot3,sub_plot4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))
sub_plot1.plot(x,y);
sub_plot2.scatter(x,y);
sub_plot3.bar(shop.keys(),shop.values());
sub_plot4.hist(a);

# %%
data = pd.read_csv('marine-economy.csv')
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag
# 0  Proportion     Actual                    LEED        43.1    R
# 1  Proportion     Actual  Environmental Accounts         NaN    F
# ...

# %%
type(data['flag'][0])
# Out:
# str

# %%
added_column=pd.Series(['$400.00','$400.00','$400.00','$400.00','$400.00','$400.00','$400.00','$400.00','$400.00'])
data['added_column']= added_column

# %%
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag added_column
# 0  Proportion     Actual                    LEED        43.1    R      $400.00
# ...

# %%
type(data['added_column'][0])
# Out:
# str

# %%
data['added_column']=data['added_column'].str.replace('[\$\.]','')
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag added_column
# 0  Proportion     Actual                    LEED        43.1    R        40000
# ...

# %%
data['added_column']=data['added_column'].str[:-2]
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag added_column
# 0  Proportion     Actual                    LEED        43.1    R          400
# ...

# %%
data['added_column']=data['added_column'].astype(int)
type(data['added_column'][0])
# Out:
# numpy.int32

# %%
data['n_added_column']=data['added_column']
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag  \
# 0  Proportion     Actual                    LEED        43.1    R
# 1  Proportion     Actual  Environmental Accounts         NaN    F
# ...

# %%
type(data['n_added_column'][0])
# Out:
# numpy.int32

# %%
data['n_added_column']=data['n_added_column'].cumsum()
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag  \
# 0  Proportion     Actual                    LEED        43.1    R
# 1  Proportion     Actual  Environmental Accounts         NaN    F
# ...

# %%
data.plot(x='year', y='n_added_column');

# %%
data.plot(x='year', y='n_added_column',kind='scatter');

# %%
data.plot(x='added_column', y='n_added_column',kind='scatter');

# %%
data.plot(x='added_column', y='n_added_column',kind='bar');

# %%
x=np.random.rand(4,4)
x
df=pd.DataFrame(x,index=['a','b','c','d'],columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# a  0.662125  0.641717  0.211680  0.953232
# b  0.254342  0.414241  0.863122  0.357922
# c  0.860529  0.111735  0.285410  0.258927
# d  0.415626  0.416776  0.634390  0.570526

# %%
np.random.seed(seed=0)
x=np.random.rand(10,4)
x
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.548814  0.715189  0.602763  0.544883
# 1  0.423655  0.645894  0.437587  0.891773
# 2  0.963663  0.383442  0.791725  0.528895
# 3  0.568045  0.925597  0.071036  0.087129
# 4  0.020218  0.832620  0.778157  0.870012
# 5  0.978618  0.799159  0.461479  0.780529
# 6  0.118274  0.639921  0.143353  0.944669
# 7  0.521848  0.414662  0.264556  0.774234
# 8  0.456150  0.568434  0.018790  0.617635
# 9  0.612096  0.616934  0.943748  0.681820

# %%
df.plot();

# %%
df.plot(kind='bar');

# %%
df.plot.bar();

# %%
df.plot.hist();

# %%
df.plot.hist(x='a',y='b');

# %%
df.plot.scatter(x='a',y='b'); # scatter can only be plotted by giving x, y coordinates.

# %%
data
# Out:
#    year                   category                                 variable  \
# 0  2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 1  2007  Fisheries and aquaculture       Contribution to marine economy GDP
# 2  2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 3  2007  Fisheries and aquaculture                Contribution to total GDP
# 4  2007  Fisheries and aquaculture                                      GDP
# 5  2007  Fisheries and aquaculture                           Gross earnings
# 6  2007  Fisheries and aquaculture                  Wage and salary earners
# 7  2008  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 8  2008  Fisheries and aquaculture       Contribution to marine economy GDP
#
#         units  magnitude                  source  data_value flag  \
# 0  Proportion     Actual                    LEED        43.1    R
# 1  Proportion     Actual  Environmental Accounts         NaN    F
# ...

# %%
data['data_value'].plot.hist();

# %%
Outliers:
data shown out of normal distribution.  This donot represent data. They can mess up with result.
# Out:
#   File "<ipython-input-47-e90ef8362d6e>", line 1
#     Outliers:
#              ^
# SyntaxError: invalid syntax

# %%
data['data_value'].plot.hist(bins=20);

# %%
data['data_value'].plot.hist(bins=5);

# %% [markdown]
# # Pyplot Vs Object Oriented Method Plot

# %%
heart_disease=pd.read_csv('heart_failure_clinical_records_dataset.csv')
heart_disease
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# # Pyplot Method

# %%
over_forty = heart_disease[heart_disease['age']>40]
over_forty
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# # Object Oriented Method

# %%
over_forty.plot(kind='scatter', x='age',
                 y='platelets',
               c = 'DEATH_EVENT');

# %% [markdown]
# In scatter plot there is third parameter which does color-coding on the basis of suspectibility.
# over_40.plot(kind=scatter, x=age,y=chol, c =target)
# c is showing suspectibility of disease wrt occurence.

# %%
figure, ax=plt.subplots(figsize=(6,5))
over_forty.plot(kind='scatter', x='age',
                 y='platelets',
               c = 'DEATH_EVENT',ax=ax);

# %% [markdown]
# If ponder upon the graph, it can be seen that x axis is more defined. Therefore OO is better than py.
#
# ax is Base class for subplots, which are :class:`Axes` instances with
# additional methods to facilitate generating and manipulating a set
# of :class:`Axes` within a figure.
#
# In other words, assigned data to to axes and to suspectibility variable is given to ax which after that save and plot it.

# %%
#Creating figure
figure, sub_plot=plt.subplots(figsize=(6,4))
#Plotting Data
sub_plot.scatter(x=over_forty['age'],
          y=over_forty['platelets'],
          c= over_forty['DEATH_EVENT'], )

# %% [markdown]
# above graph DOES NOT HAVE NAME Of AXIS, IT WOULD BE GIVEN MANUALLY in this method of "ax.scatter" while in previous method column name is only given which not only plot data but also gives name to axis and to label c.

# %% [markdown]
# Customization

# %%
#Creating figure
figure, ax=plt.subplots(figsize=(6,4))# here variable must be ax.
#Plotting Data
sub_plot=ax.scatter(x=over_forty['age'],
          y=over_forty['platelets'],
          c= over_forty['DEATH_EVENT'], ) # IN THIS FRAMEWORK IT DOES NOT HAVE GIVEN NAME TO AXIS, IT WOULD BE GIVEN MANUALLY
#Customization
ax.set(title = 'Occurence of Heart Disease', xlabel='AGE', ylabel='PLATELETS' );

# %% [markdown]
# Setting Legend

# %%
#Creating figure
figure, ax=plt.subplots(figsize=(6,4))
#Plotting Data
sub_plot=ax.scatter(x=over_forty['age'],
          y=over_forty['platelets'],
          c= over_forty['DEATH_EVENT'], )
#Customization
ax.set(title = 'Occurence of Heart Disease', xlabel='AGE', ylabel='PLATELETS' );
#setting Legend 
ax.legend(*sub_plot.legend_elements(), title='Death Rate'); #must place *.
#Meanline: to show mean value of any column on y-axis.
ax.axhline(y=over_forty['creatinine_phosphokinase'].mean(), linestyle='-', linewidth=3);

# %% [markdown]
# In last line of above code *subplot.legendelement is directing the legend to sub_plot to get given values to c, which is called legend, DEATH- EVENT IS GIVEN.

# %%
#ejection_fraction	high_blood_pressure	platelets	serum_creatinine	serum_sodium

# %%
figure, plot1=plt.subplots(figsize=(10,5))
plotting=plot1.scatter(x=over_forty['age'], y=over_forty['creatinine_phosphokinase'],c=over_forty['DEATH_EVENT'])
plot1.set(title='HEART DISEASE OCCURENCE', xlabel='AGE', ylabel='creatinine_phosphokinase');
plot1.legend(*plotting.legend_elements(), title= 'Death Rate' )
plot1.axhline(y = over_forty['creatinine_phosphokinase'].mean(),linestyle='--')
plt.style.use('dark_background')

# %%
#creating plot area
figure, (plot1,plot2)=plt.subplots(nrows=2, ncols=1, figsize=(10,8), sharex=True) #sharex:to share x axis values.

#ADDING DATA TO PLOTS
plotting1=plot1.scatter(x=over_forty['age'], y=over_forty['creatinine_phosphokinase'],c=over_forty['DEATH_EVENT'])
plotting2=plot2.scatter(x=over_forty['age'], y=over_forty['ejection_fraction'], c=over_forty['DEATH_EVENT'])

#CUSTOMIZATION
plot1.set(title='HEART DISEASE OCCURENCE', xlabel='AGE', ylabel='creatinine_phosphokinase');
plot2.set(title='HEART DISEASE OCCURENCE', xlabel='AGE', ylabel='ejection_fraction')

#Adding Legend
plot1.legend(*plotting1.legend_elements(), title= 'Death Rate' )
plot2.legend(*plotting2.legend_elements(), title = 'Death Rate')

#Meanline
plot1.axhline(y = over_forty['creatinine_phosphokinase'].mean(),linestyle='--')
plot1.axhline(y = over_forty['ejection_fraction'].mean(),linestyle='--')

#Giving style to fig
plt.style.use('dark_background')

#Naming the fig
figure.suptitle('Patient Data', fontsize=32, fontweight='bold')

#Saving the fig
figure.savefig('patient_data_report.png')

# %%
over_forty
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...
